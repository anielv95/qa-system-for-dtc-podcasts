# %%
import os
import json

# %% [markdown]
# # read json

# %%
path_cwd = os.getcwd()
data_path = os.path.join(os.path.dirname(path_cwd),"data")
documents_path = os.path.join(data_path,"episode.json")

# %%
with open(documents_path, "r", encoding="utf-8") as f:
    episode = json.load(f)

# %%
episode.keys()

# %%
episode.get('episode')
